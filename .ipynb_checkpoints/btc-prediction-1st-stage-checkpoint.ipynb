# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
from tensorflow.keras import layers
import sklearn.preprocessing as skp
from keras.models import Sequential
# Out:
# 2023-09-19 19:45:59.644403: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2023-09-19 19:45:59.796588: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2023-09-19 19:45:59.800458: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-09-19 19:46:01.990348: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
data = pd.read_csv("BTC-USD.csv")

# %%
pd.set_option("display.max.columns", None)

# %%
data.head()
# Out:
#          Date        Open        High         Low       Close   Adj Close  \
# 0  2015-01-14  223.893997  223.893997  171.509995  178.102997  178.102997
# 1  2015-01-15  176.897003  229.067001  176.897003  209.843994  209.843994
# 2  2015-01-16  209.070007  221.591003  199.770996  208.097000  208.097000
# 3  2015-01-17  207.834000  211.731003  194.875000  199.259995  199.259995
# 4  2015-01-18  200.050003  218.695007  194.505997  210.339005  210.339005
#
#      Volume
# 0  97638704
# 1  81773504
# 2  38421000
# 3  23469700
# 4  30085100

# %%
plt.rcParams ['figure.figsize'] = [18, 6]

# %%
data.plot(x = "Date", y = ["Close"])
plt.grid(True)

# %%
df = data.filter(['Close'])
vals = df.values
scaler = skp.MinMaxScaler(feature_range=(0, 1))
scaled = scaler.fit_transform(vals)

# %%
train_amount = round(len(df)*0.8)
train_data = scaled[:train_amount]
X_train = []
y_train = []

for i in range(14, len(train_data)):
  X_train.append(train_data[i-14:i, 0])
  y_train.append(train_data[i, 0])

X_train, y_train = np.array(X_train), np.array(y_train)    
X_train = np.expand_dims(X_train, 1)

# %%
model = Sequential([
    layers.Dense(16, activation='relu', input_shape=(X_train.shape[1:])),
    layers.LSTM(32, return_sequences=True),
    layers.Dropout(0.2),
    layers.LSTM(32, return_sequences=True),
    layers.Dropout(0.2),
    layers.LSTM(32),
    layers.Dropout(0.4),
    layers.Flatten(),
    layers.Dense(16, activation='relu'),
    layers.Dense(8, activation='elu'),
    layers.Dense(1)
    ])
    
model.compile(optimizer='adam', loss='mse')
# Out:
# 2023-09-19 19:46:07.169118: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2023-09-19 19:46:07.170420: W tensorflow/core/common_runtime/gpu/gpu_device.cc:1960] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...

# %%
model.fit(X_train, y_train, batch_size=128, epochs=100)
# Out:
# Epoch 1/100
# 20/20 [==============================] - 13s 25ms/step - loss: 0.0608
# Epoch 2/100
# 20/20 [==============================] - 0s 24ms/step - loss: 0.0430
# Epoch 3/100
# 20/20 [==============================] - 0s 25ms/step - loss: 0.0108
# Epoch 4/100
# 20/20 [==============================] - 0s 25ms/step - loss: 0.0059
# Epoch 5/100
# 20/20 [==============================] - 0s 24ms/step - loss: 0.0047
# Epoch 6/100
# 20/20 [==============================] - 0s 24ms/step - loss: 0.0036
# Epoch 7/100
# 20/20 [==============================] - 0s 23ms/step - loss: 0.0032
# Epoch 8/100
# 20/20 [==============================] - 0s 22ms/step - loss: 0.0032
# Epoch 9/100
# 20/20 [==============================] - 0s 22ms/step - loss: 0.0028
# Epoch 10/100
# 20/20 [==============================] - 0s 22ms/step - loss: 0.0025
# Epoch 11/100
# 20/20 [==============================] - 0s 22ms/step - loss: 0.0028
# Epoch 12/100
# 20/20 [==============================] - 1s 29ms/step - loss: 0.0025
# Epoch 13/100
# 20/20 [==============================] - 0s 23ms/step - loss: 0.0024
# Epoch 14/100
# 20/20 [==============================] - 0s 25ms/step - loss: 0.0021
# Epoch 15/100
# 20/20 [==============================] - 0s 23ms/step - loss: 0.0019
# Epoch 16/100
# 20/20 [==============================] - 0s 23ms/step - loss: 0.0020
# Epoch 17/100
# 20/20 [==============================] - 0s 22ms/step - loss: 0.0018
# Epoch 18/100
# 20/20 [==============================] - 0s 23ms/step - loss: 0.0018
# Epoch 19/100
# 20/20 [==============================] - 0s 24ms/step - loss: 0.0016
# Epoch 20/100
# 20/20 [==============================] - 1s 26ms/step - loss: 0.0017
# Epoch 21/100
# 20/20 [==============================] - 0s 23ms/step - loss: 0.0016
# Epoch 22/100
# 20/20 [==============================] - 0s 24ms/step - loss: 0.0016
# Epoch 23/100
# 20/20 [==============================] - 0s 24ms/step - loss: 0.0015
# Epoch 24/100
# 20/20 [==============================] - 0s 24ms/step - loss: 0.0013
# Epoch 25/100
# 20/20 [==============================] - 0s 24ms/step - loss: 0.0016
# Epoch 26/100
# 20/20 [==============================] - 0s 24ms/step - loss: 0.0015
# Epoch 27/100
# 20/20 [==============================] - 0s 24ms/step - loss: 0.0014
# Epoch 28/100
# 20/20 [==============================] - 0s 24ms/step - loss: 0.0015
# Epoch 29/100
# 20/20 [==============================] - 0s 23ms/step - loss: 0.0015
# Epoch 30/100
# 20/20 [==============================] - 0s 23ms/step - loss: 0.0015
# Epoch 31/100
# 20/20 [==============================] - 1s 25ms/step - loss: 0.0013
# Epoch 32/100
# 20/20 [==============================] - 0s 23ms/step - loss: 0.0014
# Epoch 33/100
# 20/20 [==============================] - 0s 23ms/step - loss: 0.0012
# Epoch 34/100
# 20/20 [==============================] - 0s 25ms/step - loss: 0.0012
# Epoch 35/100
# 20/20 [==============================] - 0s 24ms/step - loss: 0.0013
# Epoch 36/100
# 20/20 [==============================] - 0s 24ms/step - loss: 0.0012
# Epoch 37/100
# 20/20 [==============================] - 0s 23ms/step - loss: 0.0013
# Epoch 38/100
# 20/20 [==============================] - 0s 24ms/step - loss: 0.0012
# Epoch 39/100
# 20/20 [==============================] - 0s 24ms/step - loss: 0.0012
# Epoch 40/100
# 20/20 [==============================] - 0s 24ms/step - loss: 0.0012
# Epoch 41/100
# 20/20 [==============================] - 1s 26ms/step - loss: 0.0012
# Epoch 42/100
# 20/20 [==============================] - 0s 24ms/step - loss: 0.0011
# Epoch 43/100
# 20/20 [==============================] - 0s 25ms/step - loss: 0.0011
# Epoch 44/100
# 20/20 [==============================] - 0s 24ms/step - loss: 0.0011
# Epoch 45/100
# 20/20 [==============================] - 0s 23ms/step - loss: 0.0011
# Epoch 46/100
# 20/20 [==============================] - 0s 25ms/step - loss: 0.0012
# Epoch 47/100
# 20/20 [==============================] - 0s 24ms/step - loss: 0.0013
# Epoch 48/100
# 20/20 [==============================] - 0s 24ms/step - loss: 0.0011
# Epoch 49/100
# 20/20 [==============================] - 0s 23ms/step - loss: 0.0010
# Epoch 50/100
# 20/20 [==============================] - 0s 24ms/step - loss: 0.0012
# Epoch 51/100
# 20/20 [==============================] - 0s 24ms/step - loss: 0.0011
# Epoch 52/100
# 20/20 [==============================] - 0s 24ms/step - loss: 0.0010
# Epoch 53/100
# 20/20 [==============================] - 0s 23ms/step - loss: 9.9934e-04
# Epoch 54/100
# 20/20 [==============================] - 1s 25ms/step - loss: 0.0011
# Epoch 55/100
# 20/20 [==============================] - 0s 25ms/step - loss: 0.0011
# Epoch 56/100
# 20/20 [==============================] - 0s 24ms/step - loss: 9.7198e-04
# Epoch 57/100
# 20/20 [==============================] - 0s 23ms/step - loss: 9.3387e-04
# Epoch 58/100
# 20/20 [==============================] - 0s 24ms/step - loss: 9.8159e-04
# Epoch 59/100
# 20/20 [==============================] - 0s 24ms/step - loss: 9.6600e-04
# Epoch 60/100
# 20/20 [==============================] - 0s 24ms/step - loss: 8.4908e-04
# Epoch 61/100
# 20/20 [==============================] - 0s 24ms/step - loss: 8.4270e-04
# Epoch 62/100
# 20/20 [==============================] - 0s 24ms/step - loss: 0.0011
# Epoch 63/100
# 20/20 [==============================] - 0s 24ms/step - loss: 9.0457e-04
# Epoch 64/100
# 20/20 [==============================] - 0s 24ms/step - loss: 9.9237e-04
# Epoch 65/100
# 20/20 [==============================] - 1s 26ms/step - loss: 8.1906e-04
# Epoch 66/100
# 20/20 [==============================] - 0s 24ms/step - loss: 0.0010
# Epoch 67/100
# 20/20 [==============================] - 0s 23ms/step - loss: 9.2161e-04
# Epoch 68/100
# 20/20 [==============================] - 0s 24ms/step - loss: 7.3566e-04
# Epoch 69/100
# 20/20 [==============================] - 0s 24ms/step - loss: 9.7310e-04
# Epoch 70/100
# 20/20 [==============================] - 0s 23ms/step - loss: 8.1771e-04
# Epoch 71/100
# 20/20 [==============================] - 0s 24ms/step - loss: 8.7454e-04
# Epoch 72/100
# 20/20 [==============================] - 0s 24ms/step - loss: 9.7678e-04
# Epoch 73/100
# 20/20 [==============================] - 0s 24ms/step - loss: 7.9381e-04
# Epoch 74/100
# 20/20 [==============================] - 0s 24ms/step - loss: 0.0011
# Epoch 75/100
# 20/20 [==============================] - 0s 24ms/step - loss: 0.0010
# Epoch 76/100
# 20/20 [==============================] - 1s 26ms/step - loss: 0.0010
# Epoch 77/100
# 20/20 [==============================] - 0s 24ms/step - loss: 8.2552e-04
# Epoch 78/100
# 20/20 [==============================] - 0s 24ms/step - loss: 7.2941e-04
# Epoch 79/100
# 20/20 [==============================] - 0s 24ms/step - loss: 8.2669e-04
# Epoch 80/100
# 20/20 [==============================] - 0s 23ms/step - loss: 7.9602e-04
# Epoch 81/100
# 20/20 [==============================] - 0s 24ms/step - loss: 8.9822e-04
# Epoch 82/100
# 20/20 [==============================] - 0s 23ms/step - loss: 8.5389e-04
# Epoch 83/100
# 20/20 [==============================] - 1s 26ms/step - loss: 8.4361e-04
# Epoch 84/100
# 20/20 [==============================] - 0s 24ms/step - loss: 7.5555e-04
# Epoch 85/100
# 20/20 [==============================] - 0s 23ms/step - loss: 7.9201e-04
# Epoch 86/100
# 20/20 [==============================] - 0s 24ms/step - loss: 7.7972e-04
# Epoch 87/100
# 20/20 [==============================] - 1s 27ms/step - loss: 7.9029e-04
# Epoch 88/100
# 20/20 [==============================] - 0s 23ms/step - loss: 8.6293e-04
# Epoch 89/100
# 20/20 [==============================] - 0s 24ms/step - loss: 8.6022e-04
# Epoch 90/100
# 20/20 [==============================] - 0s 23ms/step - loss: 8.0706e-04
# Epoch 91/100
# 20/20 [==============================] - 0s 24ms/step - loss: 8.0990e-04
# Epoch 92/100
# 20/20 [==============================] - 0s 24ms/step - loss: 7.3527e-04
# Epoch 93/100
# 20/20 [==============================] - 0s 24ms/step - loss: 7.7293e-04
# Epoch 94/100
# 20/20 [==============================] - 0s 23ms/step - loss: 8.1966e-04
# Epoch 95/100
# 20/20 [==============================] - 0s 24ms/step - loss: 7.1308e-04
# Epoch 96/100
# 20/20 [==============================] - 1s 28ms/step - loss: 7.7925e-04
# Epoch 97/100
# 20/20 [==============================] - 0s 24ms/step - loss: 8.8842e-04
# Epoch 98/100
# 20/20 [==============================] - 0s 24ms/step - loss: 7.9567e-04
# Epoch 99/100
# 20/20 [==============================] - 0s 23ms/step - loss: 7.2787e-04
# Epoch 100/100
# 20/20 [==============================] - 0s 23ms/step - loss: 7.3708e-04

# %%
test_data = scaled[train_amount - 14: , :]

X_test = []
y_test = vals[train_amount:, :]
for i in range(14, len(test_data)):
    X_test.append(test_data[i-14:i, 0])
    
X_test = np.array(X_test)
X_test = np.expand_dims(X_test, 1)
 
pred = model.predict(X_test)
pred = scaler.inverse_transform(pred)
# Out:
# 20/20 [==============================] - 3s 8ms/step

# %%
pred[0:10]
# Out:
# array([[47257.3  ],
#        [46425.688],
#        [47606.05 ],
#        [49228.12 ],
#        [48983.94 ],
#        [48927.055],
#        [49757.754],
#        [50412.27 ],
#        [49398.09 ],
#        [48596.58 ]], dtype=float32)

# %%
y_test[0:10]
# Out:
# array([[48936.613281],
#        [48628.511719],
#        [50784.539063],
#        [50822.195313],
#        [50429.859375],
#        [50809.515625],
#        [50640.417969],
#        [47588.855469],
#        [46444.710938],
#        [47178.125   ]])

# %%
def check_accuracy():
    for i in range (0,10):
        print(int(abs(y_test[0:10][i] - pred[0:10][i])))

check_accuracy()
# Out:
# 1679
# 2202
# 3178
# 1594
# 1445
# 1882
# 882
# 2823
# 2953
# 1418
