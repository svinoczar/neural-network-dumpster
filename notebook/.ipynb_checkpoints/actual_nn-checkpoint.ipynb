# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import missingno as msno

import datetime
from pandas.tseries.offsets import DateOffset
from pandas.tseries.offsets import MonthEnd

import statsmodels.api as sm
from scipy import stats
import itertools

import gc
import warnings
warnings.filterwarnings("ignore")

# %%
df = pd.read_csv("../datasets/binance-solana.csv")

# %%
df['Date'] = pd.to_datetime(df['Date'])
df['Close Time'] = pd.to_datetime(df['Close Time'], format='mixed').dt.strftime('%Y-%m-%d %H:%M:%S')
df['Close Time'] = pd.to_datetime(df['Close Time'], format='%Y-%m-%d %H:%M:%S')

# %%
df.set_index(df['Date'], inplace=True)
df.index = pd.to_datetime(df.index)
df.index
# Out:
# DatetimeIndex(['2020-08-11 09:00:00', '2020-08-11 09:15:00',
#                '2020-08-11 09:30:00', '2020-08-11 09:45:00',
#                '2020-08-11 10:00:00', '2020-08-11 10:15:00',
#                '2020-08-11 10:30:00', '2020-08-11 10:45:00',
#                '2020-08-11 11:00:00', '2020-08-11 11:15:00',
#                ...
#                '2023-09-22 21:45:00', '2023-09-22 22:00:00',
#                '2023-09-22 22:15:00', '2023-09-22 22:30:00',
#                '2023-09-22 22:45:00', '2023-09-22 23:00:00',
#                '2023-09-22 23:15:00', '2023-09-22 23:30:00',
#                '2023-09-22 23:45:00', '2023-09-23 00:00:00'],
#               dtype='datetime64[ns]', name='Date', length=109119, freq=None)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 109119 entries, 0 to 109118
# Data columns (total 12 columns):
#  #   Column                        Non-Null Count   Dtype
# ---  ------                        --------------   -----
#  0   Date                          109119 non-null  datetime64[ns]
#  1   Open                          109119 non-null  float64
#  2   High                          109119 non-null  float64
#  3   Low                           109119 non-null  float64
#  4   Close                         109119 non-null  float64
#  5   Volume                        109119 non-null  float64
#  6   Close Time                    109119 non-null  datetime64[ns]
#  7   Quote Asset Volume            109119 non-null  float64
#  8   Number of Trades              109119 non-null  int64
#  9   Taker Buy Base Asset Volume   109119 non-null  float64
#  10  Taker Buy Quote Asset Volume  109119 non-null  float64
#  11  Ignore                        109119 non-null  float64
# dtypes: datetime64[ns](2), float64(9), int64(1)
# memory usage: 10.0 MB

# %%
ax, fig = plt.subplots(figsize = (10,5))

plt.plot(df["Open"], label="Opening price")
plt.plot(df["Close"], label="Closing price")

plt.xticks(alpha=0.75, weight="bold")
plt.yticks(alpha=0.75, weight="bold")

plt.xlabel("Date",alpha=0.75, weight="bold")
plt.ylabel("Price",alpha=0.75, weight="bold")

plt.legend()

# %%
p = d = q = range(0,2)
pdq = list(itertools.product(p,d,q))

seasonal_pdq = [(x[0],x[1],x[2],12) for x in list(itertools.product(p,d,q))]

# %%
def sarimax_function(data,pdq,s_pdq):

    result_list = []
    for param in pdq:
        for s_param in s_pdq:

            model = sm.tsa.statespace.SARIMAX(data, order=param, seasonal_order=s_param,
            enforce_invertibility=False,enforce_stationarity=False)

            results = model.fit()
            result_list.append([param,s_param,results.aic])
            print("ARIMA Parameters: {} x: {}. AIC: {}".format(param,s_param,results.aic))

    return result_list,results

# %%
result_list,results = sarimax_function(df["Close"],pdq,seasonal_pdq)

gc.collect()
# Out:
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            1     M =           10
#  This problem is unconstrained.
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  5.73724D+00    |proj g|=  1.20082D-07
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     1      0      1      0     0     0   1.201D-07   5.737D+00
#   F =   5.7372357475024396
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# ARIMA Parameters: (0, 0, 0) x: (0, 0, 0, 12). AIC: 1252084.8550634375
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            2     M =           10
#  This problem is unconstrained.
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  5.37432D+00    |proj g|=  1.39755D-01
#
# At iterate    5    f=  5.36533D+00    |proj g|=  9.89717D-03
#
# At iterate   10    f=  5.34369D+00    |proj g|=  1.56212D-01
#
# At iterate   15    f=  5.16890D+00    |proj g|=  6.07458D-01
#
# At iterate   20    f=  5.05750D+00    |proj g|=  1.25443D-03
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     2     22     40      1     0     0   8.417D-06   5.058D+00
#   F =   5.0575043300051048
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# ARIMA Parameters: (0, 0, 0) x: (0, 0, 1, 12). AIC: 1103743.6299716542
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            1     M =           10
#  This problem is unconstrained.
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  1.93100D+00    |proj g|=  6.76893D-05
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     1      1      3      1     0     0   2.337D-05   1.931D+00
#   F =   1.9310001405807320
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# ARIMA Parameters: (0, 0, 0) x: (0, 1, 0, 12). AIC: 421419.6086800578
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            2     M =           10
#  This problem is unconstrained.
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  1.93162D+00    |proj g|=  4.79479D-02
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     2      4      7      1     0     0   2.758D-07   1.931D+00
#   F =   1.9305379895261039
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# ARIMA Parameters: (0, 0, 0) x: (0, 1, 1, 12). AIC: 421320.74975819787
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            2     M =           10
#  This problem is unconstrained.
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  1.93095D+00    |proj g|=  1.01139D-02
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     2      1     20      1     0     0   1.011D-02   1.931D+00
#   F =   1.9309533194077007
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
#
#  Warning:  more than 10 function and gradient
#    evaluations in the last line search.  Termination
#    may possibly be caused by a bad search direction.
# ARIMA Parameters: (0, 0, 0) x: (1, 0, 0, 12). AIC: 421411.39052089775
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            3     M =           10
#  This problem is unconstrained.
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  1.93297D+00    |proj g|=  7.92819D-02
#
# At iterate    5    f=  1.93286D+00    |proj g|=  4.92695D-01
#
# At iterate   10    f=  1.93071D+00    |proj g|=  5.18565D-01
#
# At iterate   15    f=  1.93064D+00    |proj g|=  4.29857D-03
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     3     18     23      1     0     0   1.711D-06   1.931D+00
#   F =   1.9306386773297706
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# ARIMA Parameters: (0, 0, 0) x: (1, 0, 1, 12). AIC: 421344.72366309445
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            2     M =           10
#  This problem is unconstrained.
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  1.93054D+00    |proj g|=  5.00211D-06
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     2      0      1      0     0     0   5.002D-06   1.931D+00
#   F =   1.9305357850085025
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# ARIMA Parameters: (0, 0, 0) x: (1, 1, 0, 12). AIC: 421320.2686486856
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            3     M =           10
#  This problem is unconstrained.
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  1.93158D+00    |proj g|=  4.73070D-02
#
# At iterate    5    f=  1.93054D+00    |proj g|=  1.76799D-03
#
# At iterate   10    f=  1.93040D+00    |proj g|=  1.88482D-03
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     3     13     16      1     0     0   4.192D-06   1.930D+00
#   F =   1.9304018363423976
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# ARIMA Parameters: (0, 0, 0) x: (1, 1, 1, 12). AIC: 421293.03595969215
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            2     M =           10
#  This problem is unconstrained.
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  5.36377D+00    |proj g|=  9.51335D-02
#
# At iterate    5    f=  5.36344D+00    |proj g|=  9.95776D-03
#
# At iterate   10    f=  5.36219D+00    |proj g|=  1.19913D-01
#
# At iterate   15    f=  5.29479D+00    |proj g|=  4.16513D-01
#
# At iterate   20    f=  5.05090D+00    |proj g|=  3.43542D-02
#
# At iterate   25    f=  5.04908D+00    |proj g|=  7.67830D-07
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     2     25     43      1     0     0   7.678D-07   5.049D+00
#   F =   5.0490819181791275
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# ARIMA Parameters: (0, 0, 1) x: (0, 0, 0, 12). AIC: 1101905.5396595765
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            3     M =           10
#  This problem is unconstrained.
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  5.27161D+00    |proj g|=  3.38798D-02
#
# At iterate    5    f=  5.26944D+00    |proj g|=  4.13630D-02
#
# At iterate   10    f=  5.25636D+00    |proj g|=  5.12063D-02
#
# At iterate   15    f=  5.03596D+00    |proj g|=  4.60092D+00
#
# At iterate   20    f=  4.37919D+00    |proj g|=  5.52226D-01
#
# At iterate   25    f=  4.37751D+00    |proj g|=  7.90064D-04
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     3     26     62      1     0     0   5.800D-04   4.378D+00
#   F =   4.3775146783903534
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# ARIMA Parameters: (0, 0, 1) x: (0, 0, 1, 12). AIC: 955346.048382554
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            2     M =           10
#  This problem is unconstrained.
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  1.62767D+00    |proj g|=  3.84400D-01
#
# At iterate    5    f=  1.51001D+00    |proj g|=  1.62005D-03
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     2      8     11      1     0     0   3.433D-08   1.510D+00
#   F =   1.5100111565887626
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# ARIMA Parameters: (0, 0, 1) x: (0, 1, 0, 12). AIC: 329545.8147916184
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            3     M =           10
#  This problem is unconstrained.
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  1.62328D+00    |proj g|=  4.12712D-01
#
# At iterate    5    f=  1.49933D+00    |proj g|=  7.72978D-03
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     3      9     12      1     0     0   1.334D-06   1.499D+00
#   F =   1.4992974209153167
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# ARIMA Parameters: (0, 0, 1) x: (0, 1, 1, 12). AIC: 327209.6705457169
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            3     M =           10
#  This problem is unconstrained.
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  5.23685D+00    |proj g|=  1.33171D-02
#
# At iterate    5    f=  4.58065D+00    |proj g|=  3.00954D+00
#   ys=-1.026E+01  -gs= 5.722E-01 BFGS update SKIPPED
#
# At iterate   10    f=  3.04714D+00    |proj g|=  1.38763D+01
#
# At iterate   15    f=  2.58728D+00    |proj g|=  2.55461D+00
#
# At iterate   20    f=  2.26694D+00    |proj g|=  6.56311D-01
#
# At iterate   25    f=  2.07737D+00    |proj g|=  1.43606D+00
#
# At iterate   30    f=  2.01727D+00    |proj g|=  9.33322D-01
#
# At iterate   35    f=  1.97997D+00    |proj g|=  9.86786D-01
#
# At iterate   40    f=  1.95908D+00    |proj g|=  6.55895D-01
#
# At iterate   45    f=  1.94949D+00    |proj g|=  2.76605D+00
#
# At iterate   50    f=  1.94366D+00    |proj g|=  7.58590D-01
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     3     50     95      1     1     0   7.586D-01   1.944D+00
#   F =   1.9436583164441616
#
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT
# ARIMA Parameters: (0, 0, 1) x: (1, 0, 0, 12). AIC: 424186.103664141
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            4     M =           10
#  This problem is unconstrained.
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  5.23675D+00    |proj g|=  1.33169D-02
#
# At iterate    5    f=  4.67475D+00    |proj g|=  5.50614D-01
#
# At iterate   10    f=  4.03985D+00    |proj g|=  8.39885D+00
#
# At iterate   15    f=  2.89088D+00    |proj g|=  2.41154D+00
#
# At iterate   20    f=  1.83103D+00    |proj g|=  7.11435D+00
#
# At iterate   25    f=  1.50507D+00    |proj g|=  2.47218D+00
#
# At iterate   30    f=  1.49935D+00    |proj g|=  1.93498D-04
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     4     31     67      1     0     0   2.752D-05   1.499D+00
#   F =   1.4993547468444566
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# ARIMA Parameters: (0, 0, 1) x: (1, 0, 1, 12). AIC: 327224.18124184053
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            3     M =           10
#  This problem is unconstrained.
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  1.62574D+00    |proj g|=  3.94735D-01
#
# At iterate    5    f=  1.49943D+00    |proj g|=  8.24999D-03
#
# At iterate   10    f=  1.49939D+00    |proj g|=  4.13891D-07
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     3     10     13      1     0     0   4.139D-07   1.499D+00
#   F =   1.4993854267594440
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# ARIMA Parameters: (0, 0, 1) x: (1, 1, 0, 12). AIC: 327228.8767651275
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            4     M =           10
#  This problem is unconstrained.
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  1.62332D+00    |proj g|=  4.13057D-01
#
# At iterate    5    f=  1.49927D+00    |proj g|=  1.63293D-03
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     4      8     11      1     0     0   2.991D-05   1.499D+00
#   F =   1.4992661009000083
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# ARIMA Parameters: (0, 0, 1) x: (1, 1, 1, 12). AIC: 327204.835328216
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            1     M =           10
#  This problem is unconstrained.
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  7.71196D-01    |proj g|=  1.55229D-06
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     1      0      1      0     0     0   1.552D-06   7.712D-01
#   F =  0.77119595306416078
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# ARIMA Parameters: (0, 1, 0) x: (0, 0, 0, 12). AIC: 168306.2624048163
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            2     M =           10
#  This problem is unconstrained.
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  7.71158D-01    |proj g|=  4.35463D-04
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     2      3      5      1     0     0   3.859D-06   7.712D-01
#   F =  0.77115793091077778
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# ARIMA Parameters: (0, 1,
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# ARIMA Parameters: (0, 1, 1) x: (1, 1, 0, 12). AIC: 212386.45115203687
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            4     M =           10
#  This problem is unconstrained.
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  9.02655D-01    |proj g|=  5.76747D-01
#
# At iterate    5    f=  7.73776D-01    |proj g|=  1.00747D-01
#
# At iterate   10    f=  7.71527D-01    |proj g|=  5.75084D-02
#
# At iterate   15    f=  7.71492D-01    |proj g|=  1.58643D-03
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     4     17     30      1     0     0   2.269D-04   7.715D-01
#   F =  0.77149203843530978
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# ARIMA Parameters: (0, 1, 1) x: (1, 1, 1, 12). AIC: 168376.87948404514
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            2     M =           10
#  This problem is unconstrained.
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  7.71193D-01    |proj g|=  1.02910D-01
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     2      1     17      1     0     0   1.029D-01   7.712D-01
#   F =  0.77119252508975666
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
#
#  Warning:  more than 10 function and gradient
#    evaluations in the last line search.  Termination
#    may possibly be caused by a bad search direction.
# ARIMA Parameters: (1, 0, 0) x: (0, 0, 0, 12). AIC: 168307.51429053833
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            3     M =           10
#  This problem is unconstrained.
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  2.99005D+00    |proj g|=  2.77770D+01
#
# At iterate    5    f=  8.95437D-01    |proj g|=  1.78045D+00
#
# At iterate   10    f=  7.71511D-01    |proj g|=  1.57333D+00
#
# At iterate   15    f=  7.71155D-01    |proj g|=  2.49002D-03
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     3     15     33      1     0     0   2.490D-03   7.712D-01
#   F =  0.77115468698172485
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
#
#  Warning:  more than 10 function and gradient
#    evaluations in the last line search.  Termination
#    may possibly be caused by a bad search direction.
# ARIMA Parameters: (1, 0, 0) x: (0, 0, 1, 12). AIC: 168301.25657751766
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            2     M =           10
#  This problem is unconstrained.
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  1.09070D+00    |proj g|=  2.74938D-05
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     2      1     21      1     0     0   2.749D-05   1.091D+00
#   F =   1.0907049979988992
#
# ABNORMAL_TERMINATION_IN_LNSRCH
#
#  Line search cannot locate an adequate point after 20 function
#   and gradient evaluations.  Previous x, f and g restored.
#  Possible causes: 1 error in function or gradient evaluation;
#                   2 rounding error dominate computation.
# ARIMA Parameters: (1, 0, 0) x: (0, 1, 0, 12). AIC: 238037.27735328375
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            3     M =           10
#  This problem is unconstrained.
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  1.06006D+00    |proj g|=  4.10835D-01
#
# At iterate    5    f=  7.73591D-01    |proj g|=  1.04335D+00
#
# At iterate   10    f=  7.71578D-01    |proj g|=  3.61726D-02
#
# At iterate   15    f=  7.71540D-01    |proj g|=  7.65741D-02
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     3     18     37      1     0     0   1.317D-05   7.715D-01
#   F =  0.77153973649705787
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# ARIMA Parameters: (1, 0, 0) x: (0, 1, 1, 12). AIC: 168385.2890136449
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            3     M =           10
#  This problem is unconstrained.
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  1.26710D+00    |proj g|=  1.89582D+00
#
# At iterate    5    f=  1.07380D+00    |proj g|=  5.93438D-01
#
# At iterate   10    f=  9.45106D-01    |proj g|=  7.52268D+00
#
# At iterate   15    f=  7.78624D-01    |proj g|=  4.21821D+00
#
# At iterate   20    f=  7.71155D-01    |proj g|=  4.25341D-04
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     3     21     41      1     0     0   4.253D-04   7.712D-01
#   F =  0.77115470247893858
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
#
#  Warning:  more than 10 function and gradient
#    evaluations in the last line search.  Termination
#    may possibly be caused by a bad search direction.
# ARIMA Parameters: (1, 0, 0) x: (1, 0, 0, 12). AIC: 168301.2599595986
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            4     M =           10
#  This problem is unconstrained.
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  1.18497D+00    |proj g|=  1.58186D+00
#
# At iterate    5    f=  9.35283D-01    |proj g|=  2.12452D+00
#
# At iterate   10    f=  8.11777D-01    |proj g|=  1.04212D+01
#
# At iterate   15    f=  7.71177D-01    |proj g|=  6.41744D-02
#
#  Bad direction in the line search;
#    refresh the lbfgs memory and restart the iteration.
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     4     17     67      2     0     0   2.177D-03   7.712D-01
#   F =  0.77117686850004352
#
# ABNORMAL_TERMINATION_IN_LNSRCH
#
#  Line search cannot locate an adequate point after 20 function
#   and gradient evaluations.  Previous x, f and g restored.
#  Possible causes: 1 error in function or gradient evaluation;
#                   2 rounding error dominate computation.
# ARIMA Parameters: (1, 0, 0) x: (1, 0, 1, 12). AIC: 168308.0974277125
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            3     M =           10
#  This problem is unconstrained.
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  1.07898D+00    |proj g|=  4.48213D-01
#
# At iterate    5    f=  9.57989D-01    |proj g|=  1.73677D-03
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     3      7     10      1     0     0   2.436D-06   9.580D-01
#   F =  0.95798905135507095
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# ARIMA Parameters: (1, 0, 0) x: (1, 1, 0, 12). AIC: 209075.61458962798
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            4     M =           10
#  This problem is unconstrained.
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  1.
-04
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     3     12     29      1     0     0   2.236D-05   7.715D-01
#   F =  0.77150114542508619
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# ARIMA Parameters: (1, 1, 0) x: (0, 1, 1, 12). AIC: 168376.86697527996
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            3     M =           10
#  This problem is unconstrained.
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  7.71110D-01    |proj g|=  1.42188D-04
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     3      1      4      1     0     0   4.399D-05   7.711D-01
#   F =  0.77111015115982495
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# ARIMA Parameters: (1, 1, 0) x: (1, 0, 0, 12). AIC: 168291.5371688179
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            4     M =           10
#  This problem is unconstrained.
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  7.71110D-01    |proj g|=  1.78630D-04
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     4      3     16      1     0     0   1.484D-05   7.711D-01
#   F =  0.77111019459359209
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
#
#  Warning:  more than 10 function and gradient
#    evaluations in the last line search.  Termination
#    may possibly be caused by a bad search direction.
# ARIMA Parameters: (1, 1, 0) x: (1, 0, 1, 12). AIC: 168293.54664771634
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            3     M =           10
#  This problem is unconstrained.
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  9.91688D-01    |proj g|=  3.35606D-01
#
# At iterate    5    f=  9.73172D-01    |proj g|=  9.05397D-04
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     3      6      9      1     0     0   5.700D-06   9.732D-01
#   F =  0.97317214303973609
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# ARIMA Parameters: (1, 1, 0) x: (1, 1, 0, 12). AIC: 212389.14215270593
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            4     M =           10
#  This problem is unconstrained.
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  9.02673D-01    |proj g|=  5.76754D-01
#
# At iterate    5    f=  7.73761D-01    |proj g|=  1.01080D-01
#
# At iterate   10    f=  7.71536D-01    |proj g|=  1.04054D-01
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     4     14     25      1     0     0   1.955D-04   7.715D-01
#   F =  0.77150106233628157
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# ARIMA Parameters: (1, 1, 0) x: (1, 1, 1, 12). AIC: 168378.8488421454
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            3     M =           10
#  This problem is unconstrained.
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  7.70686D-01    |proj g|=  3.66485D-02
#
# At iterate    5    f=  7.70312D-01    |proj g|=  1.15754D-03
#
# At iterate   10    f=  7.70270D-01    |proj g|=  5.65317D-03
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     3     13     15      1     0     0   2.912D-06   7.703D-01
#   F =  0.77026453812676854
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# ARIMA Parameters: (1, 1, 1) x: (0, 0, 0, 12). AIC: 168106.99227170972
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            4     M =           10
#  This problem is unconstrained.
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  7.70648D-01    |proj g|=  3.67323D-02
#
# At iterate    5    f=  7.70272D-01    |proj g|=  1.30966D-03
#
# At iterate   10    f=  7.70228D-01    |proj g|=  3.46789D-03
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     4     14     16      1     0     0   1.238D-05   7.702D-01
#   F =  0.77021935219458459
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# ARIMA Parameters: (1, 1, 1) x: (0, 0, 1, 12). AIC: 168099.13098424175
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            3     M =           10
#  This problem is unconstrained.
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  1.11097D+00    |proj g|=  3.97578D-01
#
# At iterate    5    f=  1.09087D+00    |proj g|=  2.59635D-01
#
# At iterate   10    f=  1.09075D+00    |proj g|=  7.13234D-02
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     3     14     21      1     0     0   8.141D-06   1.091D+00
#   F =   1.0907448618664310
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# ARIMA Parameters: (1, 1, 1) x: (0, 1, 0, 12). AIC: 238047.97716400618
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            4     M =           10
#  This problem is unconstrained.
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  9.00379D-01    |proj g|=  5.80560D-01
#
# At iterate    5    f=  7.73700D-01    |proj g|=  1.57110D-01
#
# At iterate   10    f=  7.71113D-01    |proj g|=  3.53181D-03
#
# At iterate   15    f=  7.70951D-01    |proj g|=  1.11094D-01
#
# At iterate   20    f=  7.70633D-01    |proj g|=  9.44430D-03
#
# At iterate   25    f=  7.70616D-01    |proj g|=  2.70341D-03
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     4     28     47      1     0     0   3.360D-03   7.706D-01
#   F =  0.77061550085657426
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
#
#  Warning:  more than 10 function and gradient
#    evaluations in the last line search.  Termination
#    may possibly be caused by a bad search direction.
# ARIMA Parameters: (1, 1, 1) x: (0, 1, 1, 12). AIC: 168185.58567593707
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            4     M =           10
#  This problem is unconstrained.
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  7.70652D-01    |proj g|=  3.67249D-02
#
# At iterate    5    f=  7.70276D-01    |proj g|=  1.29996D-03
#
# At iterate   10    f=  7.70232D-01    |proj g|=  3.53880D-03
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     4     14     16      1     0     0   3.485D-06   7.702D-01
#   F =  0.77022390177664291
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# ARIMA Parameters: (1, 1, 1) x: (1, 0, 0, 12). AIC: 168100.123875931
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            5     M =           10
#  This problem is unconstrained.
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  7.70648D-01    |proj g|=  3.67276D-02
#
# At iterate    5    f=  7.70272D-01    |proj g|=  1.27418D-03
#
# At iterate   10    f=  7.70228D-01    |proj g|=  3.72489D-03
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     5     14     16      1     0     0   2.141D-05   7.702D-01
#   F =  0.77021950871933453
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# ARIMA Parameters: (1, 1, 1) x: (1, 0, 1, 12). AIC: 168101.16514389013
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            4     M =           10
#  This problem is unconstrained.
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  9.88481D-01    |proj g|=  3.41704D-01
#
# At iterate    5    f=  9.63044D-01    |proj g|=  2.20463D-01
#
# At iterate   10    f=  9.58162D-01    |proj g|=  2.88109D-01
#
# At iterate   15    f=  9.58041D-01    |proj g|=  1.10128D-02
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     4     17     35      1     0     0   6.459D-03   9.580D-01
#   F =  0.95804131657569436
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# ARIMA Parameters: (1, 1, 1) x: (1, 1, 0, 12). AIC: 209089.0208468464
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            5     M =           10
#  This problem is unconstrained.
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  9.00757D-01    |proj g|=  5.79592D-01
#
# At iterate    5    f=  7.75835D-01    |proj g|=  1.27923D-01
#
# At iterate   10    f=  7.71822D-01    |proj g|=  3.77603D-02
#
# At iterate   15    f=  7.70951D-01    |proj g|=  3.21620D-02
#
# At iterate   20    f=  7.70651D-01    |proj g|=  2.67642D-02
#
# At iterate   25    f=  7.70617D-01    |proj g|=  2.89784D-03
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     5     28     54      1     0     0   5.489D-04   7.706D-01
#   F =  0.77061530036257775
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
#
#  Warning:  more than 10 function and gradient
#    evaluations in the last line search.  Termination
#    may possibly be caused by a bad search direction.
# ARIMA Parameters: (1, 1, 1) x: (1, 1, 1, 12). AIC: 168187.54192052825
# 5673

# %%
results_dataframe = pd.DataFrame(result_list, columns=["dpq","s_dpq","aic"]).sort_values(by="aic")
results_dataframe.head()
# Out:
#           dpq          s_dpq            aic
# 57  (1, 1, 1)  (0, 0, 1, 12)  168099.130984
# 60  (1, 1, 1)  (1, 0, 0, 12)  168100.123876
# 61  (1, 1, 1)  (1, 0, 1, 12)  168101.165144
# 56  (1, 1, 1)  (0, 0, 0, 12)  168106.992272
# 59  (1, 1, 1)  (0, 1, 1, 12)  168185.585676

# %%
model = sm.tsa.statespace.SARIMAX(df["Close"], order=(1, 1, 1), seasonal_order=(0, 0, 1, 12),
            enforce_invertibility=False,enforce_stationarity=False).fit()
print(model.summary().tables[1])
# Out:
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            4     M =           10
#  This problem is unconstrained.
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  7.70648D-01    |proj g|=  3.67323D-02
#
# At iterate    5    f=  7.70272D-01    |proj g|=  1.30966D-03
#
# At iterate   10    f=  7.70228D-01    |proj g|=  3.46789D-03
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     4     14     16      1     0     0   1.238D-05   7.702D-01
#   F =  0.77021935219458459
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          0.7555      0.008     97.381      0.000       0.740       0.771
# ma.L1         -0.7839      0.007   -106.579      0.000      -0.798      -0.769
# ma.S.L12       0.0055      0.001      5.035      0.000       0.003       0.008
# sigma2         0.2733      0.000   1305.727      0.000       0.273       0.274
# ==============================================================================

# %%
df__prediction = df[["Close"]]

df_prediction["Forcasting"] = model.get_predictoi(start=pd.to_datetime("2020-08-11 09:00:00"), end=pd.to_datetime("2023-09-23"))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[105], line 3
#       1 df__prediction = df[["Close"]]
# ----> 3 df_prediction["Forcasting"] = model.get_predict(start=pd.to_datetime("2020-08-11 09:00:00"), end=pd.to_datetime("2023-09-23"))
#
# File ~/.local/lib/python3.11/site-packages/statsmodels/base/wrapper.py:34, in ResultsWrapper.__getattribute__(self, attr)
#      31 except AttributeError:
#      32     pass
# ---> 34 obj = getattr(results, attr)
#      35 data = results.model.data
#      36 how = self._wrap_attrs.get(attr)
#
# AttributeError: 'SARIMAXResults' object has no attribute 'get_predict'
